# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
df=pd.read_csv('Amazon Sales data.csv')
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df=df.isnull().sum()
df
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.info()
df
# Out:
# <class 'pandas.core.series.Series'>
# Index: 14 entries, Region to Total Profit
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 14 non-null     int64
# dtypes: int64(1)
# memory usage: 780.0+ bytes
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df=df.drop_duplicates()
df
# Out:
# Region    0
# dtype: int64

# %%
df.nunique()
df
# Out:
# Region    0
# dtype: int64

# %%
df.drop(columns=['Order ID'],inplace=True)
df
# Out:
# Region    0
# dtype: int64

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df['Order Date']=pd.to_datetime(df['Order Date'])
#       2 df['Ship Date']=pd.to_datetime(df['Ship Date'])
#       3 df
#
# NameError: name 'df' is not defined

# %%
df['year']=df['Order Date'].dt.year
df['month']=df['Order Date'].dt.month 
df['day']=df['Order Date'].dt.day
df['day_name']=df['Order Date'].dt.day_name()
df['dayofweek']=df['Order Date'].dt.dayofweek
df['quarter']=df['Order Date'].dt.quarter
df['lead time']=(df['Ship Date']-df['Order Date'])
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df['lead time'] = df['lead time'].dt.days
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
cd='Amazon_sales_clean_data.csv'
cd
# Out:
# 'Amazon_sales_clean_data.csv'

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Ship Date       100 non-null    object
#  7   Units Sold      100 non-null    int64
#  8   Unit Price      100 non-null    float64
#  9   Unit Cost       100 non-null    float64
#  10  Total Revenue   100 non-null    float64
#  11  Total Cost      100 non-null    float64
#  12  Total Profit    100 non-null    float64
#  13  year            100 non-null    int64
#  14  month           100 non-null    int64
#  15  day             100 non-null    int64
#  16  day_name        100 non-null    object
# ...

# %%
df.to_csv(cd,index=False)
print(f"Cleaned Data is saved in {cd}")
# Out:
# Cleaned Data is saved in Amazon_sales_clean_data.csv

# %%
cd=pd.read_csv('Amazon_sales_clean_data.csv')
cd
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
unique_years=sorted(cd['year'].unique())
unique_years
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
unique_country=(cd['Country'].unique())
ucl=len(unique_country)
print(ucl)
# Out:
# 76

# %%
unique_items=(cd['Item Type'].unique())
uil=len(unique_items)
print(uil)
# Out:
# 12

# %%
unique_region=(cd['Region'].unique())
ur=len(unique_region)
print(ur)
# Out:
# 7

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Ship Date       100 non-null    object
#  7   Units Sold      100 non-null    int64
#  8   Unit Price      100 non-null    float64
#  9   Unit Cost       100 non-null    float64
#  10  Total Revenue   100 non-null    float64
#  11  Total Cost      100 non-null    float64
#  12  Total Profit    100 non-null    float64
#  13  year            100 non-null    int64
#  14  month           100 non-null    int64
#  15  day             100 non-null    int64
#  16  day_name        100 non-null    object
# ...

# %%
cd_2010=cd[cd['year']== 2010]
cd_2010
# Out:
#                           Region       Country        Item Type Sales Channel  \
# 0          Australia and Oceania        Tuvalu        Baby Food       Offline
# 18                          Asia  Turkmenistan        Household       Offline
# 27            Sub-Saharan Africa          Mali           Fruits        Online
# 41  Middle East and North Africa    Azerbaijan        Cosmetics        Online
# 47                        Europe   Switzerland    Personal Care        Online
# 50                        Europe       Albania          Clothes        Online
# 56         Australia and Oceania          Fiji          Clothes       Offline
# 63  Middle East and North Africa         Libya          Clothes       Offline
# 68                        Europe     Lithuania  Office Supplies       Offline
# 93                        Europe       Romania        Cosmetics        Online
#
#    Order Priority  Order Date   Ship Date  Units Sold  Unit Price  Unit Cost  \
# ...

# %%
region_unit_sold_2010=cd_2010.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2010= region_unit_sold_2010.sort_values(by='Units Sold', ascending=False)
r_us_2010=px.bar(
    region_unit_sold_2010,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2010]",
    text='Units Sold',
    labels={'Units Sold':'Total_Units_Sold','Region':'Regions'}
    )
r_us_2010.update_layout(showlegend=False)
r_us_2010.show()

# %%
country_unit_sold_2010=cd_2010.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2010 = country_unit_sold_2010.sort_values(by='Units Sold', ascending=False)
c_us_2010=px.bar(country_unit_sold_2010,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2010]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2010.update_layout(showlegend=False)
c_us_2010.show()

# %%
items_sold_2010=cd_2010.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2010 = items_sold_2010.sort_values(by='Units Sold', ascending=False)
item_s_2010=px.bar(items_sold_2010,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2010]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': 'Items','Unit Sold':'Total Units Sold'})
item_s_2010.update_layout(showlegend=False)
item_s_2010.show()

# %%
country_sales_channel_2010= cd_2010.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2010=country_sales_channel_2010.sort_values(by='Units Sold',ascending=False)
csc_2010= px.bar(
    country_sales_channel_2010,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2010]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
csc_2010.update_traces(textposition='inside')
csc_2010.show()

# %%
region_sales_channel_2010 = cd_2010.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2010=region_sales_channel_2010.sort_values(by='Units Sold',ascending=False)

rsc_2010 = px.bar(
    region_sales_channel_2010,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2010]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)


rsc_2010.update_traces(textposition='inside')


rsc_2010.show()

# %%
region_order_priority_2010 = cd_2010.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2010=region_order_priority_2010.sort_values(by='Units Sold',ascending=False)
rop_2010 = px.bar(
    region_order_priority_2010,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2010]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# rop_2010.update_traces(textposition='outside')
rop_2010.show()

# %%
item_order_priority_2010 = cd_2010.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()


item_order_priority_2010['Country_ItemType'] = item_order_priority_2010['Country'] + " - " + item_order_priority_2010['Item Type']

iop_2010 = px.bar(
    item_order_priority_2010,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2010]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

iop_2010.update_traces(textposition='inside')

iop_2010.update_layout(
    xaxis_title="Country - Item Type",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

iop_2010.show()

# %%
month_item_sales_2010 = cd_2010.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()


mis_2010= px.bar(
    month_item_sales_2010,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Types Ordered in Each Month [2010]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)


mis_2010.update_traces(textposition='inside')


mis_2010.show()

# %%
cd_2010['Unit Price'] = cd_2010['Unit Price'].round(2)
cd_2010['Unit Cost'] = cd_2010['Unit Cost'].round(2)
item_cost_price_2010 = cd_2010.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

icp_2010 = make_subplots(specs=[[{"secondary_y": True}]])

icp_2010.add_trace(
    go.Scatter(
        x=item_cost_price_2010['Item Type'],
        y=item_cost_price_2010['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2010['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top right',
        textfont=dict(color='blue', size=12), 
    ),
    secondary_y=False
)

icp_2010.add_trace(
    go.Scatter(
        x=item_cost_price_2010['Item Type'],
        y=item_cost_price_2010['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2010['Unit Cost'].round(0).astype(int),# Display Unit Cost as text
        textposition='bottom left',
        textfont=dict(color='green', size=12), # Position of text
    ),
    secondary_y=True
)

icp_2010.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2010]",
    xaxis_title="Item Type",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

icp_2010.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)

icp_2010.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_16912\3776068849.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_16912\3776068849.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cd_2010.loc[:,'Total Revenue'] = cd_2010['Total Revenue'].round(2)
cd_2010.loc[:,'Total Cost'] = cd_2010['Total Cost'].round(2)
item_total_revenue_cost_2010 = cd_2010.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

itrc_2010 = make_subplots(specs=[[{"secondary_y": True}]])

itrc_2010.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2010['Item Type'],
        y=item_total_revenue_cost_2010['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2010['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12), # Position of text
    ),
    secondary_y=False
)

itrc_2010.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2010['Item Type'],
        y=item_total_revenue_cost_2010['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2010['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right', 
        textfont=dict(color='green', size=12), # Position of text
    ),
    secondary_y=True
)

itrc_2010.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2010]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue",
    legend_title="Metrics",
    template="plotly_white"
)

itrc_2010.update_layout(
    yaxis2=dict(title="Total Cost")
)

itrc_2010.show()

# %%
# Round the values for better visualization
cd_2010.loc[:,'Total Revenue'] = cd_2010['Total Revenue'].round(2)
cd_2010.loc[:,'Total Cost'] = cd_2010['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2010 = cd_2010.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2010 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2010.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2010['Country'],
        y=item_total_revenue_cost_2010['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2010['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12), # Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2010.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2010['Country'],
        y=item_total_revenue_cost_2010['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2010['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom left',
        textfont=dict(color='green', size=12), # Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2010.update_layout(
    title="Total Revenue V/S Total Cost by Country [2010]",
    xaxis_title="Item Type",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2010.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2010.show()

# %%
lead_time_avg_2010 = cd_2010.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2010=lead_time_avg_2010.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2010= px.bar(
    lead_time_avg_2010,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2010]",
    color='Item Type',
    text='lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2010.update_layout(
    xaxis_title="Item Type",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2010.show()

# %%
# Create a treemap chart
region_country_2010= px.treemap(
    cd_2010,
    path=['Region', 'Country'],  # Define hierarchy: Region > Country
    title="Countries under Each Region[2010]",
    # labels={'parent': 'Regions', 'labels': 'Countries'}
)

# Show the chart
region_country_2010.show()

# %%
cd_2012=cd[cd['year']== 2011]

cd_2012
# Out:
#                                Region                           Country  \
# 6                  Sub-Saharan Africa                            Angola
# 10                               Asia                        Kyrgyzstan
# 36       Middle East and North Africa                             Syria
# 53                 Sub-Saharan Africa                      Sierra Leone
# 62                 Sub-Saharan Africa                          Cameroon
# 72                 Sub-Saharan Africa  Democratic Republic of the Congo
# 77                               Asia                              Laos
# 83                 Sub-Saharan Africa                            Zambia
# 86                 Sub-Saharan Africa             Sao Tome and Principe
# 94  Central America and the Caribbean                         Nicaragua
# 95                 Sub-Saharan Africa                              Mali
# 96                               Asia                          Malaysia
#
# ...

# %%
region_unit_sold_2012=cd_2012.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2012 = region_unit_sold_2012.sort_values(by='Units Sold', ascending=False)
r_us_2012=px.bar(
    region_unit_sold_2012,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2011]",
    text='Units Sold',
    labels={'Units Sold':'Total Units Sold','Region':'Regions'}
    )
r_us_2012.update_layout(showlegend=False)
r_us_2012.show()

# %%
region_sales_channel_2012 = cd_2012.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2012=region_sales_channel_2012.sort_values(by='Units Sold',ascending=False)
# Visualization: Country vs Sales Channel
rsc_2012 = px.bar(
    region_sales_channel_2012,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2011]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)

# Add text on bars
rsc_2012.update_traces(textposition='inside')

# Show the chart
rsc_2012.show()

# %%
region_order_priority_2012 = cd_2012.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2012=region_order_priority_2012.sort_values(by='Units Sold',ascending=False)
rop_2012 = px.bar(
    region_order_priority_2012,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2011]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
rop_2012.update_traces(textposition='inside')
rop_2012.show()

# %%
region_country_2012 = px.treemap(
    cd_2012,
    path=['Region', 'Country'],  
    title="Countries under Each Region[2011]",
    
)


region_country_2012.show()

# %%
country_unit_sold_2012=cd_2012.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2012 = country_unit_sold_2012.sort_values(by='Units Sold', ascending=False)
c_us_2012=px.bar(country_unit_sold_2012,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2011]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2012.update_layout(showlegend=False)
c_us_2012.show()

# %%
country_sales_channel_2012= cd_2012.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2012=country_sales_channel_2012.sort_values(by='Units Sold',ascending=False)
csc_2012= px.bar(
    country_sales_channel_2012,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2011]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
csc_2012.update_traces(textposition='inside')
csc_2012.show()

# %%
item_order_priority_2012 = cd_2012.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()
# Combine 'Country' and 'Item Type' into a single column
item_order_priority_2012['Country_ItemType'] = item_order_priority_2012['Country'] + " - " + item_order_priority_2012['Item Type']
item_order_priority_2012=item_order_priority_2012.sort_values(by='Units Sold',ascending=False)
# Create the bar chart with combined x-axis
iop_2012 = px.bar(
    item_order_priority_2012,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2011]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

# Adjust text position for readability
# iop_2011.update_traces(textposition='inside')

# Update x-axis layout to improve readability
iop_2012.update_layout(
    xaxis_title="Country - Item Type",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

# Show the chart
iop_2012.show()

# %%
items_sold_2012=cd_2012.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2012 = items_sold_2012.sort_values(by='Units Sold', ascending=False)
item_s_2012=px.bar(items_sold_2012,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2011]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': 'Items','Unit Sold':'Total Units Sold'})
item_s_2012.update_layout(showlegend=False)
item_s_2012.show()

# %%
month_item_sales_2012 = cd_2012.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()

# Visualization: Item Type Ordered by Year
mis_2012= px.bar(
    month_item_sales_2012,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Sold in Each Month [2011]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)

# Add text on bars
# mis_2011.update_traces(textposition='inside')

# Show the chart
mis_2012.show()

# %%
lead_time_avg_2012 = cd_2012.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2012=lead_time_avg_2012.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2012= px.bar(
    lead_time_avg_2012,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2011]",
    color='Item Type',
    text='lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2012.update_layout(
    xaxis_title="Item Type",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2012.show()

# %%
# Round the values for better visualization
cd_2012['Unit Price'] = cd_2012['Unit Price'].round(2)
cd_2012['Unit Cost'] = cd_2012['Unit Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_cost_price_2012 = cd_2012.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

# Create a figure with secondary y-axis
icp_2012 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
icp_2012.add_trace(
    go.Scatter(
        x=item_cost_price_2012['Item Type'],
        y=item_cost_price_2012['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2012['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
icp_2012.add_trace(
    go.Scatter(
        x=item_cost_price_2012['Item Type'],
        y=item_cost_price_2012['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2012['Unit Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
icp_2012.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2011]",
    xaxis_title="Item's",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
icp_2012.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)


# Show the chart
icp_2012.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_10136\1055834391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cd_2011['Unit Price'] = cd_2011['Unit Price'].round(2)
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_10136\1055834391.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cd_2011['Unit Cost'] = cd_2011['Unit Cost'].round(2)

# %%
# Round the values for better visualization
cd_2012.loc[:,'Total Revenue'] = cd_2012['Total Revenue'].round(2)
cd_2012.loc[:,'Total Cost'] = cd_2012['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2012 = cd_2012.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2012 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Item Type'],
        y=item_total_revenue_cost_2012['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2012['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='bottom right',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Item Type'],
        y=item_total_revenue_cost_2012['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2012['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='top left', 
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2012.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2011]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2012.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2012.show()

# %%
# Round the values for better visualization
cd_2012.loc[:,'Total Revenue'] = cd_2012['Total Revenue'].round(2)
cd_2012.loc[:,'Total Cost'] = cd_2012['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2012 = cd_2012.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2012 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Country'],
        y=item_total_revenue_cost_2012['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2012['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12), # Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Country'],
        y=item_total_revenue_cost_2012['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2012['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
         textposition='middle right',
         textfont=dict(color='green', size=12), # Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2012.update_layout(
    title="Total Revenue V/S Total Cost by Country [2011]",
    xaxis_title="Country",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2012.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2012.show()

# %%
cd_2012=cd[cd['year']== 2012]
cd_2012
# Out:
#                                Region         Country        Item Type  \
# 1   Central America and the Caribbean         Grenada           Cereal
# 7                  Sub-Saharan Africa    Burkina Faso       Vegetables
# 15                             Europe        Bulgaria          Clothes
# 19              Australia and Oceania      East Timor             Meat
# 29                 Sub-Saharan Africa      The Gambia        Household
# 30                             Europe     Switzerland        Cosmetics
# 38                               Asia          Brunei  Office Supplies
# 39                             Europe        Bulgaria  Office Supplies
# 42                 Sub-Saharan Africa      The Gambia           Cereal
# 43                             Europe        Slovakia       Vegetables
# 49                 Sub-Saharan Africa      Mauritania  Office Supplies
# 55                 Sub-Saharan Africa   Cote d'Ivoire          Clothes
# ...

# %%
region_unit_sold_2012=cd_2012.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2012 = region_unit_sold_2012.sort_values(by='Units Sold', ascending=False)
r_us_2012=px.bar(
    region_unit_sold_2012,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2012]",
    text='Units Sold',
    labels={'Units Sold':'Total Units Sold','Region':'Regions'}
    )
r_us_2012.update_layout(showlegend=False)
r_us_2012.show()

# %%
region_sales_channel_2012 = cd_2012.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2012=region_sales_channel_2012.sort_values(by='Units Sold',ascending=False)
# Visualization: Country vs Sales Channel
rsc_2012 = px.bar(
    region_sales_channel_2012,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2012]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)

# Add text on bars
# rsc_2012.update_traces(textposition='inside')

# Show the chart
rsc_2012.show()

# %%
region_order_priority_2012 = cd_2012.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2012=region_order_priority_2012.sort_values(by='Units Sold',ascending=False)
rop_2012 = px.bar(
    region_order_priority_2012,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2012]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# rop_2012.update_traces(textposition='inside')
rop_2012.show()

# %%
# Create a treemap chart
region_country_2012 = px.treemap(
    cd_2012,
    path=['Region', 'Country'],  # Define hierarchy: Region > Country
    title="Countries under Each Region[2012]",
    # labels={'parent': 'Regions', 'labels': 'Countries'}
)

# Show the chart
region_country_2012.show()

# %%
country_unit_sold_2012=cd_2012.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2012 = country_unit_sold_2012.sort_values(by='Units Sold', ascending=False)
c_us_2012=px.bar(country_unit_sold_2012,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2012]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2012.update_layout(showlegend=False)
c_us_2012.show()

# %%
country_sales_channel_2012= cd_2012.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2012=country_sales_channel_2012.sort_values(by='Units Sold',ascending=False)
csc_2012= px.bar(
    country_sales_channel_2012,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2012]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# csc_2012.update_traces(textposition='inside')
csc_2012.show()

# %%
item_order_priority_2012 = cd_2012.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()
# Combine 'Country' and 'Item Type' into a single column
item_order_priority_2012['Country_ItemType'] = item_order_priority_2012['Country'] + " - " + item_order_priority_2012['Item Type']
item_order_priority_2012=item_order_priority_2012.sort_values(by='Units Sold',ascending=False)
# Create the bar chart with combined x-axis
iop_2012 = px.bar(
    item_order_priority_2012,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2012]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

# Adjust text position for readability
# iop_2012.update_traces(textposition='inside')

# Update x-axis layout to improve readability
iop_2012.update_layout(
    xaxis_title="Country - Item's",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

# Show the chart
iop_2012.show()

# %%
items_sold_2012=cd_2012.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2012 = items_sold_2012.sort_values(by='Units Sold', ascending=False)
item_s_2012=px.bar(items_sold_2012,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2012]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': "Item's",'Unit Sold':'Total Units Sold'})
item_s_2012.update_layout(showlegend=False)
item_s_2012.show()

# %%
month_item_sales_2012 = cd_2012.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()

# Visualization: Item Type Ordered by Year
mis_2012= px.bar(
    month_item_sales_2012,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Sold in Each Month [2012]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)

# Add text on bars
# mis_2012.update_traces(textposition='inside')

# Show the chart
mis_2012.show()

# %%
lead_time_avg_2012 = cd_2012.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2012=lead_time_avg_2012.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2012= px.bar(
    lead_time_avg_2012,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2012]",
    color='Item Type',
    text='lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2012.update_layout(
    xaxis_title="Item's",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2012.show()

# %%
# Round the values for better visualization
cd_2012['Unit Price'] = cd_2012['Unit Price'].round(2)
cd_2012['Unit Cost'] = cd_2012['Unit Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_cost_price_2012 = cd_2012.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

# Create a figure with secondary y-axis
icp_2012 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
icp_2012.add_trace(
    go.Scatter(
        x=item_cost_price_2012['Item Type'],
        y=item_cost_price_2012['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2012['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12), # Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
icp_2012.add_trace(
    go.Scatter(
        x=item_cost_price_2012['Item Type'],
        y=item_cost_price_2012['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2012['Unit Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',
        textfont=dict(color='green', size=12), # Position of text
    ),
    secondary_y=True
)

# Update layout
icp_2012.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2012]",
    xaxis_title="Item's",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
icp_2012.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)

# Show the chart
icp_2012.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_10136\2936585539.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_10136\2936585539.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Round the values for better visualization
cd_2012.loc[:,'Total Revenue'] = cd_2012['Total Revenue'].round(2)
cd_2012.loc[:,'Total Cost'] = cd_2012['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2012 = cd_2012.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2012 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Item Type'],
        y=item_total_revenue_cost_2012['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2012['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left', 
        textfont=dict(color='blue', size=12), # Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Item Type'],
        y=item_total_revenue_cost_2012['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2012['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom left', 
        textfont=dict(color='green', size=12), # Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2012.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2012]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2012.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2012.show()

# %%
# Round the values for better visualization
cd_2012.loc[:,'Total Revenue'] = cd_2012['Total Revenue'].round(2)
cd_2012.loc[:,'Total Cost'] = cd_2012['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2012 = cd_2012.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2012 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Country'],
        y=item_total_revenue_cost_2012['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2012['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left', 
        textfont=dict(color='blue', size=12), # Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2012.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2012['Country'],
        y=item_total_revenue_cost_2012['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2012['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right', 
        textfont=dict(color='green', size=12), 
    ),
    secondary_y=True
)

# Update layout
itrc_2012.update_layout(
    title="Total Revenue V/S Total Cost by Country [2012]",
    xaxis_title="Country",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2012.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2012.show()

# %%
cd_2013=cd[cd['year']== 2013]
cd_2013
# Out:
#                                Region                Country        Item Type  \
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 31                 Sub-Saharan Africa            South Sudan    Personal Care
# 51                 Sub-Saharan Africa                Lesotho           Fruits
# 52       Middle East and North Africa           Saudi Arabia           Cereal
# 54                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 60              Australia and Oceania              Australia           Cereal
# 61                             Europe             San Marino        Baby Food
# 64  Central America and the Caribbean                  Haiti        Cosmetics
# 65                 Sub-Saharan Africa                 Rwanda        Cosmetics
# 70                               Asia           Turkmenistan  Office Supplies
# 74       Middle East and North Africa               Pakistan        Cosmetics
# ...

# %%
region_unit_sold_2013=cd_2013.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2013 = region_unit_sold_2013.sort_values(by='Units Sold', ascending=False)
r_us_2013=px.bar(
    region_unit_sold_2013,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2013]",
    text='Units Sold',
    labels={'Units Sold':'Total Units Sold','Region':'Regions'}
    )
r_us_2013.update_layout(showlegend=False)
r_us_2013.show()

# %%
region_sales_channel_2013 = cd_2013.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2013=region_sales_channel_2013.sort_values(by='Units Sold',ascending=False)
# Visualization: Country vs Sales Channel
rsc_2013 = px.bar(
    region_sales_channel_2013,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2013]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)

# Add text on bars
# rsc_2013.update_traces(textposition='inside')

# Show the chart
rsc_2013.show()

# %%
region_order_priority_2013 = cd_2013.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2013=region_order_priority_2013.sort_values(by='Units Sold',ascending=False)
rop_2013 = px.bar(
    region_order_priority_2013,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2013]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# rop_2013.update_traces(textposition='inside')
rop_2013.show()

# %%
# Create a treemap chart
region_country_2013 = px.treemap(
    cd_2013,
    path=['Region', 'Country'],  # Define hierarchy: Region > Country
    title="Countries under Each Region[2013]",
    # labels={'parent': 'Regions', 'labels': 'Countries'}
)

# Show the chart
region_country_2013.show()

# %%
country_unit_sold_2013=cd_2013.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2013 = country_unit_sold_2013.sort_values(by='Units Sold', ascending=False)
c_us_2013=px.bar(country_unit_sold_2013,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2013]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2013.update_layout(showlegend=False)
c_us_2013.show()

# %%
country_sales_channel_2013= cd_2013.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2013=country_sales_channel_2013.sort_values(by='Units Sold',ascending=False)
csc_2013= px.bar(
    country_sales_channel_2013,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2013]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# csc_2013.update_traces(textposition='inside')
csc_2013.show()

# %%
item_order_priority_2013 = cd_2013.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()
# Combine 'Country' and 'Item Type' into a single column
item_order_priority_2013['Country_ItemType'] = item_order_priority_2013['Country'] + " - " + item_order_priority_2013['Item Type']
item_order_priority_2013=item_order_priority_2013.sort_values(by='Units Sold',ascending=False)
# Create the bar chart with combined x-axis
iop_2013 = px.bar(
    item_order_priority_2013,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2013]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

# Adjust text position for readability
# iop_2011.update_traces(textposition='inside')

# Update x-axis layout to improve readability
iop_2013.update_layout(
    xaxis_title="Country - Item's",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

# Show the chart
iop_2013.show()

# %%
items_sold_2013=cd_2013.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2013 = items_sold_2013.sort_values(by='Units Sold', ascending=False)
item_s_2013=px.bar(items_sold_2013,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2013]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': "Item's",'Unit Sold':'Total Units Sold'})
item_s_2013.update_layout(showlegend=False)
item_s_2013.show()

# %%
month_item_sales_2013 = cd_2013.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()

# Visualization: Item Type Ordered by Year
mis_2013= px.bar(
    month_item_sales_2013,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Sold in Each Month [2013]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)

# Add text on bars
# mis_2011.update_traces(textposition='inside')

# Show the chart
mis_2013.show()

# %%
lead_time_avg_2013 = cd_2013.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2013=lead_time_avg_2013.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2013= px.bar(
    lead_time_avg_2013,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2013]",
    color='Item Type',
    text='lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2013.update_layout(
    xaxis_title="Item's",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2013.show()

# %%
# Round the values for better visualization
cd_2013['Unit Price'] = cd_2013['Unit Price'].round(2)
cd_2013['Unit Cost'] = cd_2013['Unit Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_cost_price_2013 = cd_2013.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

# Create a figure with secondary y-axis
icp_2013 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
icp_2013.add_trace(
    go.Scatter(
        x=item_cost_price_2013['Item Type'],
        y=item_cost_price_2013['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2013['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left', 
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
icp_2013.add_trace(
    go.Scatter(
        x=item_cost_price_2013['Item Type'],
        y=item_cost_price_2013['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2013['Unit Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right', 
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
icp_2013.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2013]",
    xaxis_title="Item's",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
icp_2013.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)

# Show the chart
icp_2013.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\1581528422.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\1581528422.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Round the values for better visualization
cd_2013.loc[:,'Total Revenue'] = cd_2013['Total Revenue'].round(2)
cd_2013.loc[:,'Total Cost'] = cd_2013['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2013 = cd_2013.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2013 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2013.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2013['Item Type'],
        y=item_total_revenue_cost_2013['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2013['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2013.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2013['Item Type'],
        y=item_total_revenue_cost_2013['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2013['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2013.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2013]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2013.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2013.show()

# %%
# Round the values for better visualization
cd_2013.loc[:,'Total Revenue'] = cd_2013['Total Revenue'].round(2)
cd_2013.loc[:,'Total Cost'] = cd_2013['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2013 = cd_2013.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2013 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2013.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2013['Country'],
        y=item_total_revenue_cost_2013['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2013['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='middle left', 
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2013.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2013['Country'],
        y=item_total_revenue_cost_2013['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2013['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
         textposition='bottom right', 
         textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2013.update_layout(
    title="Total Revenue V/S Total Cost by Country [2013]",
    xaxis_title="Country",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2013.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2013.show()

# %%
cd_2014=cd[cd['year']== 2014]
cd_2014
# Out:
#                    Region                         Country        Item Type  \
# 2                  Europe                          Russia  Office Supplies
# 3      Sub-Saharan Africa           Sao Tome and Principe           Fruits
# 9      Sub-Saharan Africa                         Senegal           Cereal
# 11     Sub-Saharan Africa                      Cape Verde          Clothes
# 14                   Asia                        Mongolia    Personal Care
# 20                 Europe                          Norway        Baby Food
# 23  Australia and Oceania                     New Zealand           Fruits
# 26  Australia and Oceania                        Kiribati           Fruits
# 28                 Europe                          Norway        Beverages
# 48                 Europe                       Macedonia          Clothes
# 59     Sub-Saharan Africa                        Djibouti        Cosmetics
# ...

# %%
region_unit_sold_2014=cd_2014.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2014 = region_unit_sold_2014.sort_values(by='Units Sold', ascending=False)
r_us_2014=px.bar(
    region_unit_sold_2014,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2014]",
    text='Units Sold',
    labels={'Units Sold':'Total Units Sold','Region':'Regions'}
    )
r_us_2014.update_layout(showlegend=False)
r_us_2014.show()

# %%
region_sales_channel_2014 = cd_2014.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2014=region_sales_channel_2014.sort_values(by='Units Sold',ascending=False)
# Visualization: Country vs Sales Channel
rsc_2014 = px.bar(
    region_sales_channel_2014,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2014]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)

# Add text on bars
rsc_2014.update_traces(textposition='inside')

# Show the chart
rsc_2014.show()

# %%
region_order_priority_2014 = cd_2014.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2014=region_order_priority_2014.sort_values(by='Units Sold',ascending=False)
rop_2014 = px.bar(
    region_order_priority_2014,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2014]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# rop_2014.update_traces(textposition='inside')
rop_2014.show()

# %%
# Create a treemap chart
region_country_2014 = px.treemap(
    cd_2014,
    path=['Region', 'Country'],  # Define hierarchy: Region > Country
    title="Countries under Each Region[2014]",
    # labels={'parent': 'Regions', 'labels': 'Countries'}
)

# Show the chart
region_country_2014.show()

# %%
country_unit_sold_2014=cd_2014.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2014 = country_unit_sold_2014.sort_values(by='Units Sold', ascending=False)
c_us_2014=px.bar(country_unit_sold_2014,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2014]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2014.update_layout(showlegend=False)
c_us_2014.show()

# %%
country_sales_channel_2014= cd_2014.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2014=country_sales_channel_2014.sort_values(by='Units Sold',ascending=False)
csc_2014= px.bar(
    country_sales_channel_2014,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2014]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
csc_2014.update_traces(textposition='inside')
csc_2014.show()

# %%
item_order_priority_2014 = cd_2014.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()
# Combine 'Country' and 'Item Type' into a single column
item_order_priority_2014['Country_ItemType'] = item_order_priority_2014['Country'] + " - " + item_order_priority_2014['Item Type']
item_order_priority_2014=item_order_priority_2014.sort_values(by='Units Sold',ascending=False)
# Create the bar chart with combined x-axis
iop_2014 = px.bar(
    item_order_priority_2014,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2014]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

# Adjust text position for readability
# iop_2011.update_traces(textposition='inside')

# Update x-axis layout to improve readability
iop_2014.update_layout(
    xaxis_title="Country - Item's",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

# Show the chart
iop_2014.show()

# %%
items_sold_2014=cd_2014.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2014 = items_sold_2014.sort_values(by='Units Sold', ascending=False)
item_s_2014=px.bar(items_sold_2014,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2014]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': "Item's",'Unit Sold':'Total Units Sold'})
item_s_2014.update_layout(showlegend=False)
item_s_2014.show()

# %%
month_item_sales_2014 = cd_2014.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()

# Visualization: Item Type Ordered by Year
mis_2014= px.bar(
    month_item_sales_2014,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Sold in Each Month [2014]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)

# Add text on bars
# mis_2011.update_traces(textposition='inside')

# Show the chart
mis_2014.show()

# %%
lead_time_avg_2014 = cd_2014.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2014=lead_time_avg_2014.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2014= px.bar(
    lead_time_avg_2014,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2014]",
    color='Item Type',
    text=lead'lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2014.update_layout(
    xaxis_title="Item's",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2014.show()

# %%
# Round the values for better visualization
cd_2014['Unit Price'] = cd_2014['Unit Price'].round(2)
cd_2014['Unit Cost'] = cd_2014['Unit Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_cost_price_2014 = cd_2014.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

# Create a figure with secondary y-axis
icp_2014 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
icp_2014.add_trace(
    go.Scatter(
        x=item_cost_price_2014['Item Type'],
        y=item_cost_price_2014['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2014['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
icp_2014.add_trace(
    go.Scatter(
        x=item_cost_price_2014['Item Type'],
        y=item_cost_price_2014['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2014['Unit Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',  
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
icp_2014.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2014]",
    xaxis_title="Item's",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
icp_2014.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)

# Show the chart
icp_2014.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\1288117009.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\1288117009.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Round the values for better visualization
cd_2014.loc[:,'Total Revenue'] = cd_2014['Total Revenue'].round(2)
cd_2014.loc[:,'Total Cost'] = cd_2014['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2014 = cd_2014.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2014 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2014.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2014['Item Type'],
        y=item_total_revenue_cost_2014['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2014['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',  
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2014.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2014['Item Type'],
        y=item_total_revenue_cost_2014['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2014['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right', 
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2014.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2014]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2014.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2014.show()

# %%
# Round the values for better visualization
cd_2014.loc[:,'Total Revenue'] = cd_2014['Total Revenue'].round(2)
cd_2014.loc[:,'Total Cost'] = cd_2014['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2014 = cd_2014.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2014 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2014.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2014['Country'],
        y=item_total_revenue_cost_2014['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2014['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top right',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2014.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2014['Country'],
        y=item_total_revenue_cost_2014['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2014['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
         textposition='bottom left', 
         textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2014.update_layout(
    title="Total Revenue V/S Total Cost by Country [2014]",
    xaxis_title="Country",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2014.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2014.show()

# %%
cd_2015=cd[cd['year']== 2015]
cd_2015
# Out:
#                           Region                Country        Item Type  \
# 5          Australia and Oceania        Solomon Islands        Baby Food
# 8             Sub-Saharan Africa  Republic of the Congo    Personal Care
# 17            Sub-Saharan Africa               Cameroon        Beverages
# 21                        Europe               Portugal        Baby Food
# 32         Australia and Oceania              Australia  Office Supplies
# 33                          Asia                Myanmar        Household
# 44                          Asia                Myanmar          Clothes
# 57                        Europe                Austria        Cosmetics
# 69            Sub-Saharan Africa             Madagascar          Clothes
# 71  Middle East and North Africa                  Libya           Fruits
# 98                 North America                 Mexico    Personal Care
#
#    Sales Channel Order Priority  Order Date   Ship Date  Units Sold  \
# ...

# %%
region_unit_sold_2015=cd_2015.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2015 = region_unit_sold_2015.sort_values(by='Units Sold', ascending=False)
r_us_2015=px.bar(
    region_unit_sold_2015,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2015]",
    text='Units Sold',
    labels={'Units Sold':'Total Units Sold','Region':'Regions'}
    )
r_us_2015.update_layout(showlegend=False)
r_us_2015.show()

# %%
region_sales_channel_2015 = cd_2015.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2015=region_sales_channel_2015.sort_values(by='Units Sold',ascending=False)
# Visualization: Country vs Sales Channel
rsc_2015 = px.bar(
    region_sales_channel_2015,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2015]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)

# Add text on bars
# rsc_2015.update_traces(textposition='inside')

# Show the chart
rsc_2015.show()

# %%
region_order_priority_2015 = cd_2015.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2015=region_order_priority_2015.sort_values(by='Units Sold',ascending=False)
rop_2015 = px.bar(
    region_order_priority_2015,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2015]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# rop_2015.update_traces(textposition='inside')
rop_2015.show()

# %%
# Create a treemap chart
region_country_2015 = px.treemap(
    cd_2015,
    path=['Region', 'Country'],  # Define hierarchy: Region > Country
    title="Countries under Each Region[2015]",
    # labels={'parent': 'Regions', 'labels': 'Countries'}
)

# Show the chart
region_country_2015.show()

# %%
country_unit_sold_2015=cd_2015.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2015 = country_unit_sold_2015.sort_values(by='Units Sold', ascending=False)
c_us_2015=px.bar(country_unit_sold_2015,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2015]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2015.update_layout(showlegend=False)
c_us_2015.show()

# %%
country_sales_channel_2015= cd_2015.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2015=country_sales_channel_2015.sort_values(by='Units Sold',ascending=False)
csc_2015= px.bar(
    country_sales_channel_2015,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2015]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
# csc_2015.update_traces(textposition='inside')
csc_2015.show()

# %%
item_order_priority_2015 = cd_2015.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()
# Combine 'Country' and 'Item Type' into a single column
item_order_priority_2015['Country_ItemType'] = item_order_priority_2015['Country'] + " - " + item_order_priority_2015['Item Type']
item_order_priority_2015=item_order_priority_2015.sort_values(by='Units Sold',ascending=False)
# Create the bar chart with combined x-axis
iop_2015 = px.bar(
    item_order_priority_2015,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2015]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

# Adjust text position for readability
# iop_2011.update_traces(textposition='inside')

# Update x-axis layout to improve readability
iop_2015.update_layout(
    xaxis_title="Country - Item's",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

# Show the chart
iop_2015.show()

# %%
items_sold_2015=cd_2015.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2015 = items_sold_2015.sort_values(by='Units Sold', ascending=False)
item_s_2015=px.bar(items_sold_2015,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2015]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': "Item's",'Unit Sold':'Total Units Sold'})
item_s_2015.update_layout(showlegend=False)
item_s_2015.show()

# %%
month_item_sales_2015 = cd_2015.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()

# Visualization: Item Type Ordered by Year
mis_2015= px.bar(
    month_item_sales_2015,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Sold in Each Month [2015]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)

# Add text on bars
# mis_2011.update_traces(textposition='inside')

# Show the chart
mis_2015.show()

# %%
lead_time_avg_2015 = cd_2015.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2015=lead_time_avg_2015.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2015= px.bar(
    lead_time_avg_2015,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2015]",
    color='Item Type',
    text='lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2015.update_layout(
    xaxis_title="Item's",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2015.show()

# %%
# Round the values for better visualization
cd_2015['Unit Price'] = cd_2015['Unit Price'].round(2)
cd_2015['Unit Cost'] = cd_2015['Unit Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_cost_price_2015 = cd_2015.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

# Create a figure with secondary y-axis
icp_2015 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
icp_2015.add_trace(
    go.Scatter(
        x=item_cost_price_2015['Item Type'],
        y=item_cost_price_2015['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2015['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left', 
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
icp_2015.add_trace(
    go.Scatter(
        x=item_cost_price_2015['Item Type'],
        y=item_cost_price_2015['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2015['Unit Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right', 
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
icp_2015.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2015]",
    xaxis_title="Item's",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
icp_2015.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)

# Show the chart
icp_2015.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\533281759.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\533281759.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Round the values for better visualization
cd_2015.loc[:,'Total Revenue'] = cd_2015['Total Revenue'].round(2)
cd_2015.loc[:,'Total Cost'] = cd_2015['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2015 = cd_2015.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2015 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2015.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2015['Item Type'],
        y=item_total_revenue_cost_2015['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2015['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2015.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2015['Item Type'],
        y=item_total_revenue_cost_2015['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2015['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2015.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2015]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2015.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2015.show()

# %%
# Round the values for better visualization
cd_2015.loc[:,'Total Revenue'] = cd_2015['Total Revenue'].round(2)
cd_2015.loc[:,'Total Cost'] = cd_2015['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2015 = cd_2015.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2015 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2015.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2015['Country'],
        y=item_total_revenue_cost_2015['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2015['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top right',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2015.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2015['Country'],
        y=item_total_revenue_cost_2015['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2015['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom left',
        textfont=dict(color='green', size=12),
    ),
    secondary_y=True
)

# Update layout
itrc_2015.update_layout(
    title="Total Revenue V/S Total Cost by Country [2015]",
    xaxis_title="Country",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2015.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2015.show()

# %%
cd_2016=cd[cd['year']== 2016]
cd_2016
# Out:
#                                Region       Country        Item Type  \
# 16                               Asia     Sri Lanka        Cosmetics
# 22  Central America and the Caribbean      Honduras           Snacks
# 24                             Europe      Moldova     Personal Care
# 45                 Sub-Saharan Africa       Comoros           Cereal
# 46                             Europe       Iceland        Cosmetics
# 67  Central America and the Caribbean        Belize          Clothes
# 82       Middle East and North Africa          Iran        Cosmetics
# 89                             Europe      Slovenia        Beverages
# 90                 Sub-Saharan Africa  Sierra Leone  Office Supplies
# 97                 Sub-Saharan Africa  Sierra Leone       Vegetables
#
#    Sales Channel Order Priority  Order Date   Ship Date  Units Sold  \
# 16       Offline              M  2016-11-19  2016-12-18        6952
# 22        Online              L  2016-06-30  2016-07-26        2225
# ...

# %%
region_unit_sold_2016=cd_2016.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2016 = region_unit_sold_2016.sort_values(by='Units Sold', ascending=False)
r_us_2016=px.bar(
    region_unit_sold_2016,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2016]",
    text='Units Sold',
    labels={'Units Sold':'Total Units Sold','Region':'Regions'}
    )
r_us_2016.update_layout(showlegend=False)
r_us_2016.show()

# %%
region_sales_channel_2016 = cd_2016.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2016=region_sales_channel_2016.sort_values(by='Units Sold',ascending=False)
# Visualization: Country vs Sales Channel
rsc_2016 = px.bar(
    region_sales_channel_2016,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2016]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)

# Add text on bars
rsc_2016.update_traces(textposition='inside')

# Show the chart
rsc_2016.show()

# %%
region_order_priority_2016 = cd_2016.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2016=region_order_priority_2016.sort_values(by='Units Sold',ascending=False)
rop_2016 = px.bar(
    region_order_priority_2016,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2016]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
rop_2016.update_traces(textposition='inside')
rop_2016.show()

# %%
# Create a treemap chart
region_country_2016 = px.treemap(
    cd_2016,
    path=['Region', 'Country'],  # Define hierarchy: Region > Country
    title="Countries under Each Region[2016]",
    # labels={'parent': 'Regions', 'labels': 'Countries'}
)

# Show the chart
region_country_2016.show()

# %%
country_unit_sold_2016=cd_2016.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2016 = country_unit_sold_2016.sort_values(by='Units Sold', ascending=False)
c_us_2016=px.bar(country_unit_sold_2016,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2016]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2016.update_layout(showlegend=False)
c_us_2016.show()

# %%
country_sales_channel_2016= cd_2016.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2016=country_sales_channel_2016.sort_values(by='Units Sold',ascending=False)
csc_2016= px.bar(
    country_sales_channel_2016,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2016]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
csc_2016.update_traces(textposition='inside')
csc_2016.show()

# %%
item_order_priority_2016 = cd_2016.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()
# Combine 'Country' and 'Item Type' into a single column
item_order_priority_2016['Country_ItemType'] = item_order_priority_2016['Country'] + " - " + item_order_priority_2016['Item Type']
item_order_priority_2016=item_order_priority_2016.sort_values(by='Units Sold',ascending=False)
# Create the bar chart with combined x-axis
iop_2016 = px.bar(
    item_order_priority_2016,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2016]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

# Adjust text position for readability
# iop_2011.update_traces(textposition='inside')

# Update x-axis layout to improve readability
iop_2016.update_layout(
    xaxis_title="Country - Item's",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

# Show the chart
iop_2016.show()

# %%
items_sold_2016=cd_2016.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2016 = items_sold_2016.sort_values(by='Units Sold', ascending=False)
item_s_2016=px.bar(items_sold_2016,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2016]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': "Item's",'Unit Sold':'Total Units Sold'})
item_s_2016.update_layout(showlegend=False)
item_s_2016.show()

# %%
month_item_sales_2016 = cd_2016.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()

# Visualization: Item Type Ordered by Year
mis_2016= px.bar(
    month_item_sales_2016,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Sold in Each Month [2016]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)

# Add text on bars
# mis_2011.update_traces(textposition='inside')

# Show the chart
mis_2016.show()

# %%
lead_time_avg_2016 = cd_2016.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2016=lead_time_avg_2016.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2016= px.bar(
    lead_time_avg_2016,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2016]",
    color='Item Type',
    text='lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2016.update_layout(
    xaxis_title="Item's",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2016.show()

# %%
# Round the values for better visualization
cd_2016['Unit Price'] = cd_2016['Unit Price'].round(2)
cd_2016['Unit Cost'] = cd_2016['Unit Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_cost_price_2016 = cd_2016.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

# Create a figure with secondary y-axis
icp_2016 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
icp_2016.add_trace(
    go.Scatter(
        x=item_cost_price_2016['Item Type'],
        y=item_cost_price_2016['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2016['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left', 
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
icp_2016.add_trace(
    go.Scatter(
        x=item_cost_price_2016['Item Type'],
        y=item_cost_price_2016['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2016['Unit Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
icp_2016.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2016]",
    xaxis_title="Item's",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
icp_2016.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)

# Show the chart
icp_2016.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\176362698.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\176362698.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Round the values for better visualization
cd_2016.loc[:,'Total Revenue'] = cd_2016['Total Revenue'].round(2)
cd_2016.loc[:,'Total Cost'] = cd_2016['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2016 = cd_2016.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2016 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2016.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2016['Item Type'],
        y=item_total_revenue_cost_2016['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2016['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2016.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2016['Item Type'],
        y=item_total_revenue_cost_2016['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2016['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2016.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2016]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2016.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2016.show()

# %%
# Round the values for better visualization
cd_2016.loc[:,'Total Revenue'] = cd_2016['Total Revenue'].round(2)
cd_2016.loc[:,'Total Cost'] = cd_2016['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2016 = cd_2016.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2016 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2016.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2016['Country'],
        y=item_total_revenue_cost_2016['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2016['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top right',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2016.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2016['Country'],
        y=item_total_revenue_cost_2016['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2016['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
         textposition='bottom left',
         textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2016.update_layout(
    title="Total Revenue V/S Total Cost by Country [2016]",
    xaxis_title="Country",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2016.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2016.show()

# %%
cd_2017=cd[cd['year']== 2017]
cd_2017
# Out:
#                                Region     Country      Item Type  \
# 12                               Asia  Bangladesh        Clothes
# 13  Central America and the Caribbean    Honduras      Household
# 25                             Europe      France      Cosmetics
# 34                 Sub-Saharan Africa    Djibouti         Snacks
# 35  Central America and the Caribbean  Costa Rica  Personal Care
# 37                 Sub-Saharan Africa  The Gambia           Meat
# 40                 Sub-Saharan Africa       Niger  Personal Care
# 73                 Sub-Saharan Africa    Djibouti         Cereal
#
#    Sales Channel Order Priority  Order Date   Ship Date  Units Sold  \
# 12        Online              L  2017-01-13  2017-03-01        8263
# 13       Offline              H  2017-02-08  2017-02-13        8974
# 25        Online              H  2017-05-22  2017-06-05        1815
# 34        Online              M  2017-02-25  2017-02-25        7327
# ...

# %%
region_unit_sold_2017=cd_2017.groupby('Region')['Units Sold'].sum().reset_index()
region_unit_sold_2017 = region_unit_sold_2017.sort_values(by='Units Sold', ascending=False)
r_us_2017=px.bar(
    region_unit_sold_2017,
    x='Region',
    y='Units Sold',
    color='Region',
    title=" Item's Unit Sold by Region's [2017]",
    text='Units Sold',
    labels={'Units Sold':'Total Units Sold','Region':'Regions'}
    )
r_us_2017.update_layout(showlegend=False)
r_us_2017.show()

# %%
region_sales_channel_2017 = cd_2017.groupby(['Region', 'Sales Channel'])['Units Sold'].sum().reset_index()
region_sales_channel_2017=region_sales_channel_2017.sort_values(by='Units Sold',ascending=False)
# Visualization: Country vs Sales Channel
rsc_2017 = px.bar(
    region_sales_channel_2017,
    x='Region',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Region [2017]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)

# Add text on bars
# rsc_2017.update_traces(textposition='inside')

# Show the chart
rsc_2017.show()

# %%
region_order_priority_2017 = cd_2017.groupby(['Region', 'Order Priority'])['Units Sold'].sum().reset_index()
region_order_priority_2017=region_order_priority_2017.sort_values(by='Units Sold',ascending=False)
rop_2017 = px.bar(
    region_order_priority_2017,
    x='Region',
    y='Units Sold',
    color='Order Priority',
    title='Order Priority in Each Region [2017]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}

# rop_2017.update_traces(textposition='inside')
rop_2017.show()

# %%
# Create a treemap chart
region_country_2017 = px.treemap(
    cd_2017,
    path=['Region', 'Country'],  # Define hierarchy: Region > Country
    title="Countries under Each Region[2017]",
    # labels={'parent': 'Regions', 'labels': 'Countries'}
)

# Show the chart
region_country_2017.show()

# %%
country_unit_sold_2017=cd_2017.groupby('Country')['Units Sold'].sum().reset_index()
country_unit_sold_2017 = country_unit_sold_2017.sort_values(by='Units Sold', ascending=False)
c_us_2017=px.bar(country_unit_sold_2017,
            x='Country',
            y='Units Sold',
            title="Item's Unit Sold by Country [2017]",
            color='Country',
            text='Units Sold'
            )
# c_us.update_traces(textposition='outside')
c_us_2017.update_layout(showlegend=False)
c_us_2017.show()

# %%
country_sales_channel_2017= cd_2017.groupby(['Country', 'Sales Channel'])['Units Sold'].sum().reset_index()
country_sales_channel_2017=country_sales_channel_2017.sort_values(by='Units Sold',ascending=False)
csc_2017= px.bar(
    country_sales_channel_2017,
    x='Country',
    y='Units Sold',
    color='Sales Channel',
    title='Sales Channels Used in Each Country [2017]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold'}
)
csc_2017.update_traces(textposition='inside')
csc_2017.show()

# %%
item_order_priority_2017 = cd_2017.groupby(['Country', 'Item Type', 'Order Priority'])['Units Sold'].sum().reset_index()
# Combine 'Country' and 'Item Type' into a single column
item_order_priority_2017['Country_ItemType'] = item_order_priority_2017['Country'] + " - " + item_order_priority_2017['Item Type']
item_order_priority_2017=item_order_priority_2017.sort_values(by='Units Sold',ascending=False)
# Create the bar chart with combined x-axis
iop_2017 = px.bar(
    item_order_priority_2017,
    x='Country_ItemType',
    y='Units Sold',
    color='Order Priority',
    title="Order Priority of Item's by Country [2017]",
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'Country_ItemType': 'Country - Item Type'}
)

# Adjust text position for readability
# iop_2011.update_traces(textposition='inside')

# Update x-axis layout to improve readability
iop_2017.update_layout(
    xaxis_title="Country - Item's",
    yaxis_title="Units Sold",
    xaxis_tickangle=45,  # Rotate x-axis labels for better readability
    template="plotly_white"
)

# Show the chart
iop_2017.show()

# %%
items_sold_2017=cd_2017.groupby('Item Type')['Units Sold'].sum().reset_index()
items_sold_2017 = items_sold_2017.sort_values(by='Units Sold', ascending=False)
item_s_2017=px.bar(items_sold_2017,
                x='Item Type',
                y='Units Sold',
                title="Items Sold by units [2017]",
                color='Item Type',
                text='Units Sold',
                labels={'Item Type': 'Items','Unit Sold':'Total Units Sold'})
item_s_2017.update_layout(showlegend=False)
item_s_2017.show()

# %%
month_item_sales_2017 = cd_2017.groupby(['month', 'Item Type'])['Units Sold'].sum().reset_index()

# Visualization: Item Type Ordered by Year
mis_2017= px.bar(
    month_item_sales_2017,
    x='month',
    y='Units Sold',
    color='Item Type',
    title='Item Sold in Each Month [2017]',
    text='Units Sold',
    labels={'Units Sold': 'Total Units Sold', 'month': 'Order Month'}
)

# Add text on bars
# mis_2011.update_traces(textposition='inside')

# Show the chart
mis_2017.show()

# %%
lead_time_avg_2017 = cd_2017.groupby('Item Type', as_index=False)['lead time'].mean()
lead_time_avg_2017=lead_time_avg_2017.sort_values(by='lead time',ascending=False)

# Create Bar Chart
lead_time_chart_2017= px.bar(
    lead_time_avg_2017,
    x='Item Type',
    y='lead time',
    title="lead time of order shipment by Item [2017]",
    color='Item Type',
    text='lead time',
    labels={'lead time': 'Average Lead Time (Days)', 'Item Type': 'Item Type'}
)

# Customize Layout
lead_time_chart_2017.update_layout(
    xaxis_title="Item's",
    yaxis_title="Lead Time (Days)",
    template="plotly_white",
    showlegend=False
)

# Show Chart
lead_time_chart_2017.show()

# %%
# Round the values for better visualization
cd_2017['Unit Price'] = cd_2017['Unit Price'].round(2)
cd_2017['Unit Cost'] = cd_2017['Unit Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_cost_price_2017= cd_2017.groupby('Item Type', as_index=False)[['Unit Price', 'Unit Cost']].mean()

# Create a figure with secondary y-axis
icp_2017 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
icp_2017.add_trace(
    go.Scatter(
        x=item_cost_price_2017['Item Type'],
        y=item_cost_price_2017['Unit Price'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Price',
        line=dict(color='blue'),
        text=item_cost_price_2017['Unit Price'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
icp_2017.add_trace(
    go.Scatter(
        x=item_cost_price_2017['Item Type'],
        y=item_cost_price_2017['Unit Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Unit Cost',
        line=dict(color='green'),
        text=item_cost_price_2017['Unit Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right', 
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
icp_2017.update_layout(
    title="Unit Price V/S  Unit Cost by Item Type [2017]",
    xaxis_title="Item's",
    yaxis_title="Unit Price($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
icp_2017.update_layout(
    yaxis2=dict(title="Unit Cost($)")
)

# Show the chart
icp_2017.show()
# Out:
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\835549846.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\uc-pc\AppData\Local\Temp\ipykernel_3400\835549846.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Round the values for better visualization
cd_2017.loc[:,'Total Revenue'] = cd_2017['Total Revenue'].round(2)
cd_2017.loc[:,'Total Cost'] = cd_2017['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2017 = cd_2017.groupby('Item Type', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2017 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2017.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2017['Item Type'],
        y=item_total_revenue_cost_2017['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2017['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='top left',
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2017.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2017['Item Type'],
        y=item_total_revenue_cost_2017['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2017['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
        textposition='bottom right',
        textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2017.update_layout(
    title="Total Revenue V/S Total Cost by Item Type [2017]",
    xaxis_title="Item's",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2017.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2017.show()

# %%
# Round the values for better visualization
cd_2017.loc[:,'Total Revenue'] = cd_2017['Total Revenue'].round(2)
cd_2017.loc[:,'Total Cost'] = cd_2017['Total Cost'].round(2)
# Aggregate Data by Item Type (calculate mean of numeric columns)
item_total_revenue_cost_2017 = cd_2017.groupby('Country', as_index=False)[['Total Revenue', 'Total Cost']].mean()

# Create a figure with secondary y-axis
itrc_2017 = make_subplots(specs=[[{"secondary_y": True}]])

# Add Unit Price line to primary y-axis with text labels
itrc_2017.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2017['Country'],
        y=item_total_revenue_cost_2017['Total Revenue'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Revenue',
        line=dict(color='blue'),
        text=item_total_revenue_cost_2017['Total Revenue'].round(0).astype(int),  # Display Unit Price as text
        textposition='middle left',  
        textfont=dict(color='blue', size=12),# Position of text
    ),
    secondary_y=False
)

# Add Unit Cost line to secondary y-axis with text labels
itrc_2017.add_trace(
    go.Scatter(
        x=item_total_revenue_cost_2017['Country'],
        y=item_total_revenue_cost_2017['Total Cost'],
        mode='lines+markers+text',  # Adding text on the markers
        name='Total Cost',
        line=dict(color='green'),
        text=item_total_revenue_cost_2017['Total Cost'].round(0).astype(int),  # Display Unit Cost as text
         textposition='bottom right',
         textfont=dict(color='green', size=12),# Position of text
    ),
    secondary_y=True
)

# Update layout
itrc_2017.update_layout(
    title="Total Revenue V/S Total Cost by Country [2017]",
    xaxis_title="Country",
    yaxis_title="Total Revenue($)",
    legend_title="Metrics",
    template="plotly_white"
)

# Update the secondary y-axis title
itrc_2017.update_layout(
    yaxis2=dict(title="Total Cost($)")
)

# Show the chart
itrc_2017.show()

# %%
unique_region_2010=(cd[cd['year']== 2010]['Region'].unique())
print(f'Unique regions in 2010: {unique_region_2010}')
unique_country_2010=(cd_2010['Country'].unique())
print(f'Unique country in 2010: {unique_country_2010}')
# Out:
# Unique regions in 2010: ['Australia and Oceania' 'Asia' 'Sub-Saharan Africa'
#  'Middle East and North Africa' 'Europe']
# Unique country in 2010: ['Tuvalu' 'Turkmenistan' 'Mali' 'Azerbaijan' 'Switzerland' 'Albania'
#  'Fiji' 'Libya' 'Lithuania' 'Romania']

# %%
unique_region_2011=(cd[cd['year']== 2011]['Region'].unique())
print(f'Unique regions in 2011: {unique_region_2011}')
unique_country_2011=(cd_2012['Country'].unique())
print(f'Unique country in 2011: {unique_country_2011}')
# Out:
# Unique regions in 2011: ['Sub-Saharan Africa' 'Asia' 'Middle East and North Africa'
#  'Central America and the Caribbean']
# Unique country in 2011: ['Grenada' 'Burkina Faso' 'Bulgaria' 'East Timor' 'The Gambia'
#  'Switzerland' 'Brunei' 'Slovakia' 'Mauritania' "Cote d'Ivoire"
#  'United Kingdom' 'Gabon' 'Monaco' 'Spain' 'Lebanon' 'Kenya' 'Mexico'
#  'Kuwait' 'Azerbaijan' 'Mozambique']

# %%
unique_region_2012=(cd[cd['year']== 2012]['Region'].unique())
print(f'Unique regions in 2012: {unique_region_2012}')
unique_country_2012=(cd_2012['Country'].unique())
print(f'Unique country in 2012: {unique_country_2012}')
# Out:
# Unique regions in 2012: ['Central America and the Caribbean' 'Sub-Saharan Africa' 'Europe'
#  'Australia and Oceania' 'Asia' 'Middle East and North Africa'
#  'North America']
# Unique country in 2012: ['Grenada' 'Burkina Faso' 'Bulgaria' 'East Timor' 'The Gambia'
#  'Switzerland' 'Brunei' 'Slovakia' 'Mauritania' "Cote d'Ivoire"
#  'United Kingdom' 'Gabon' 'Monaco' 'Spain' 'Lebanon' 'Kenya' 'Mexico'
#  'Kuwait' 'Azerbaijan' 'Mozambique']

# %%
unique_region_2013=(cd[cd['year']== 2013]['Region'].unique())
print(f'Unique regions in 2013: {unique_region_2013}')
unique_country_2013=(cd_2013['Country'].unique())
print(f'Unique country in 2013: {unique_country_2013}')
# Out:
# Unique regions in 2013: ['Sub-Saharan Africa' 'Middle East and North Africa'
#  'Australia and Oceania' 'Europe' 'Central America and the Caribbean'
#  'Asia']
# Unique country in 2013: ['Rwanda' 'South Sudan' 'Lesotho' 'Saudi Arabia' 'Sao Tome and Principe'
#  'Australia' 'San Marino' 'Haiti' 'Turkmenistan' 'Pakistan' 'Samoa ']

# %%
unique_region_2014=(cd[cd['year']== 2014]['Region'].unique())
print(f'Unique regions in 2014: {unique_region_2014}')
unique_country_2014=(cd_2014['Country'].unique())
print(f'Unique country in 2014: {unique_country_2014}')
# Out:
# Unique regions in 2014: ['Europe' 'Sub-Saharan Africa' 'Asia' 'Australia and Oceania'
#  'North America']
# Unique country in 2014: ['Russia' 'Sao Tome and Principe' 'Senegal' 'Cape Verde' 'Mongolia'
#  'Norway' 'New Zealand' 'Kiribati' 'Macedonia' 'Djibouti' 'Mexico'
#  'Federated States of Micronesia' 'The Gambia' 'Australia']

# %%
unique_region_2015=(cd[cd['year']== 2015]['Region'].unique())
print(f'Unique regions in 2015: {unique_region_2015}')
unique_country_2015=(cd_2015['Country'].unique())
print(f'Unique country in 2015: {unique_country_2015}')
# Out:
# Unique regions in 2015: ['Australia and Oceania' 'Sub-Saharan Africa' 'Europe' 'Asia'
#  'Middle East and North Africa' 'North America']
# Unique country in 2015: ['Solomon Islands' 'Republic of the Congo' 'Cameroon' 'Portugal'
#  'Australia' 'Myanmar' 'Austria' 'Madagascar' 'Libya' 'Mexico']

# %%
unique_region_2016=(cd[cd['year']== 2016]['Region'].unique())
print(f'Unique regions in 2016: {unique_region_2016}')
unique_country_2016=(cd_2016['Country'].unique())
print(f'Unique country in 2016: {unique_country_2016}')
# Out:
# Unique regions in 2016: ['Asia' 'Central America and the Caribbean' 'Europe' 'Sub-Saharan Africa'
#  'Middle East and North Africa']
# Unique country in 2016: ['Sri Lanka' 'Honduras' 'Moldova ' 'Comoros' 'Iceland' 'Belize' 'Iran'
#  'Slovenia' 'Sierra Leone']

# %%
unique_region_2017=(cd[cd['year']== 2017]['Region'].unique())
print(f'Unique regions in 2017: {unique_region_2017}')
unique_country_2017=(cd_2017['Country'].unique())
print(f'Unique country in 2017: {unique_country_2017}')
# Out:
# Unique regions in 2017: ['Asia' 'Central America and the Caribbean' 'Europe' 'Sub-Saharan Africa']
# Unique country in 2017: ['Bangladesh' 'Honduras' 'France' 'Djibouti' 'Costa Rica' 'The Gambia'
#  'Niger']

# %%
years=cd.groupby('year',as_index=False)['Total Profit'].sum()
years['year'] = pd.to_numeric(years['year'], errors='coerce')  # Convert Year to numeric if needed
years['Total Profit'] = pd.to_numeric(years['Total Profit'], errors='coerce')  # Convert Profit to numeric
years['Total Profit']=years['Total Profit'].round(2)
profit_chart = px.line(
    years,
    x='year',
    y='Total Profit',
    title="Total Profit by Year's",
    text='Total Profit',  # Display profit as text on bars
    labels={'Total Profit': 'Total Profit ($)', 'year': 'Year'}
    # color='Total Profit',
    # color_continuous_scale='Blues'  # Choose a color scale
)

# Update text position and layout for better readability
profit_chart.update_traces(textposition='top right', texttemplate='%{text:,.2f}')  # Format as currency
profit_chart.update_layout(
    xaxis_title="Year",
    yaxis_title="Total Profit ($)",
    template="plotly_white"
)
profit_chart.show()

# %%
# Round the 'Total Profit' for better visualization
years['Total Profit'] = years['Total Profit'].round(2)

# Create the line chart
profit_chart = px.line(
    years,
    x='year',
    y='Total Profit',
    title="Total Profit by Year",
    text='Total Profit',  # Display profit as text on data points
    labels={'Total Profit': 'Total Profit ($)', 'Year': 'Year'},
    color='year'
)

# Update text position and layout for better readability
profit_chart.update_traces(
    textposition='top center', 
    texttemplate='%{text:,.2f}'  
)
profit_chart.update_layout(
    xaxis_title="Year",
    yaxis_title="Total Profit ($)",
    template="plotly_white"
)

# Show the chart
profit_chart.show()

# %%
sub_saharan_countries = cd[cd['Region']=="Sub-Saharan Africa"]
num_countries = len(sub_saharan_countries)

print(f"Number of countries in Sub-Saharan Africa: {num_countries}")
# Out:
# Number of countries in Sub-Saharan Africa: 36

# %%
europe_countries = cd[cd['Region']=="Europe"]
num_countries = len(europe_countries)

print(f"Number of countries in Sub-Saharan Africa: {num_countries}")
# Out:
# Number of countries in Sub-Saharan Africa: 22

# %%
mna_countries = cd[cd['Region']=="Middle East and North Africa"]
num_countries = len(mna_countries)

print(f"Number of countries in Sub-Saharan Africa: {num_countries}")
# Out:
# Number of countries in Sub-Saharan Africa: 10
